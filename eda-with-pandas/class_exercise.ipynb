# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\madhu\data-analysis-projects\eda-with-pandas\exercises\clinic_visits.csv")

# %%
print(df)
# Out:
#      visit_id  patient_id  age gender                     visit_date  \
# 0        1001         602   67      M  2024-01-28T00:00:00.000000000
# 1        1002         592   42      M  2024-03-25T00:00:00.000000000
# 2        1003         514   41      F  2024-02-18T00:00:00.000000000
# 3        1004         606   30      M  2024-03-11T00:00:00.000000000
# 4        1005         571   77      M  2024-03-21T00:00:00.000000000
# ..        ...         ...  ...    ...                            ...
# 295      1296         636   40      F  2024-02-15T00:00:00.000000000
# 296      1297         542   70      M  2024-01-29T00:00:00.000000000
# 297      1298         538   54      F  2024-03-02T00:00:00.000000000
# 298      1299         525   34      M  2024-03-02T00:00:00.000000000
# 299      1300         598   18      M  2024-02-26T00:00:00.000000000
#
#       visit_type  wait_time_min  billing_amount     diagnosis provider_id  \
# ...

# %%
df.head()
# Out:
#    visit_id  patient_id  age gender                     visit_date visit_type  \
# 0      1001         602   67      M  2024-01-28T00:00:00.000000000  Follow-up
# 1      1002         592   42      M  2024-03-25T00:00:00.000000000    Checkup
# 2      1003         514   41      F  2024-02-18T00:00:00.000000000  Follow-up
# 3      1004         606   30      M  2024-03-11T00:00:00.000000000    Checkup
# 4      1005         571   77      M  2024-03-21T00:00:00.000000000    Checkup
#
#    wait_time_min  billing_amount     diagnosis provider_id insurance_type  \
# 0           19.0          263.88       Healthy        P103        Private
# 1           14.0          146.21           NaN        P103       Medicare
# 2           22.0             NaN  Hypertension        P103       Medicaid
# 3            3.0          327.86      Diabetes        P103        Private
# 4            NaN          161.36  Hypertension        P101        Private
#
# ...

# %%
df.dtypes
# Out:
# visit_id             int64
# patient_id           int64
# age                  int64
# gender              object
# visit_date          object
# visit_type          object
# wait_time_min      float64
# billing_amount     float64
# diagnosis           object
# provider_id         object
# insurance_type      object
# is_return_visit       bool
# systolic_bp        float64
# diastolic_bp         int64
# pain_score         float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      visit_id  patient_id  age gender                     visit_date  \
# 0        1001         602   67      M  2024-01-28T00:00:00.000000000
# 1        1002         592   42      M  2024-03-25T00:00:00.000000000
# 2        1003         514   41      F  2024-02-18T00:00:00.000000000
# 3        1004         606   30      M  2024-03-11T00:00:00.000000000
# 4        1005         571   77      M  2024-03-21T00:00:00.000000000
# ..        ...         ...  ...    ...                            ...
# 295      1296         636   40      F  2024-02-15T00:00:00.000000000
# 296      1297         542   70      M  2024-01-29T00:00:00.000000000
# 297      1298         538   54      F  2024-03-02T00:00:00.000000000
# 298      1299         525   34      M  2024-03-02T00:00:00.000000000
# 299      1300         598   18      M  2024-02-26T00:00:00.000000000
#
#       visit_type  wait_time_min  billing_amount     diagnosis provider_id  \
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\madhu\Launchcode\DataAnalysisProjects\data-analysis-projects

# %%
df.describe()
# Out:
#           visit_id  patient_id         age  wait_time_min  billing_amount  \
# count   300.000000  300.000000  300.000000     273.000000      278.000000
# mean   1150.500000  576.916667   52.606667      29.677656      219.184784
# std      86.746758   43.861782   20.859106      12.991744       77.789275
# min    1001.000000  500.000000   18.000000       0.000000        0.000000
# 25%    1075.750000  538.000000   34.000000      22.000000      161.872500
# 50%    1150.500000  581.000000   52.000000      31.000000      214.785000
# 75%    1225.250000  615.000000   72.000000      39.000000      275.105000
# max    1300.000000  649.000000   89.000000      68.000000      420.990000
#
#        systolic_bp  diastolic_bp  pain_score
# count   278.000000    300.000000  274.000000
# mean    126.607914     79.593333    4.934307
# std      15.399173      9.487959    3.096032
# min      81.000000     53.000000    0.000000
# 25%     117.000000     73.000000    3.000000
# ...

# %%
df= pd.read_csv("clinic_visits.csv")

# %%
df["visit_id"]= df["visit_id"].astype(str)
df["patient_id"]= df["patient_id"].astype(str)

# %%
df[["age","pain_score"]].describe()
# Out:
#               age  pain_score
# count  300.000000  274.000000
# mean    52.606667    4.934307
# std     20.859106    3.096032
# min     18.000000    0.000000
# 25%     34.000000    3.000000
# 50%     52.000000    5.000000
# 75%     72.000000    8.000000
# max     89.000000   10.000000

# %%
df["diagnosis"].value_counts(dropna=True)
# Out:
# diagnosis
# Healthy         97
# Hypertension    54
# Diabetes        41
# Pneumonia       38
# Flu             24
# Asthma          23
# Name: count, dtype: int64

# %%
df["patient_id"].value_counts(dropna=False)
# Out:
# patient_id
# 603    7
# 598    7
# 629    6
# 553    6
# 627    6
#       ..
# 613    1
# 531    1
# 626    1
# 542    1
# 525    1
# Name: count, Length: 123, dtype: int64

# %%
df.sort_values("wait_time_min", ascending=False).head(10)
# Out:
#     visit_id  patient_id  age gender                     visit_date  \
# 116     1117         595   63      F  2024-03-21T00:00:00.000000000
# 269     1270         505   64      F  2024-02-06T00:00:00.000000000
# 178     1179         615   63      F  2024-02-23T00:00:00.000000000
# 49      1050         534   36      F  2024-02-24T00:00:00.000000000
# 109     1110         514   50      F  2024-03-26T00:00:00.000000000
# 157     1158         630   86      M  2024-01-17T00:00:00.000000000
# 207     1208         612   30      F  2024-02-20T00:00:00.000000000
# 105     1106         641   60      M  2024-02-07T00:00:00.000000000
# 32      1033         550   77      F  2024-02-16T00:00:00.000000000
# 253     1254         526   75      M  2024-01-09T00:00:00.000000000
#
#       visit_type  wait_time_min  billing_amount     diagnosis provider_id  \
# 116        Acute           68.0          245.80  Hypertension        P101
# ...

# %%
df["provider_id"].unique()
# Out:
# array(['P103', 'P101', 'P105', 'P102', 'P104'], dtype=object)

# %%
wait_greater_than_45 = df["wait_time_min"] > 45
df[wait_greater_than_45]
# Out:
#     visit_id  patient_id  age gender                     visit_date  \
# 7       1008         621   53      M  2024-01-20T00:00:00.000000000
# 8       1009         574   62      F  2024-03-26T00:00:00.000000000
# 16      1017         501   49      F  2024-02-20T00:00:00.000000000
# 18      1019         537   68      M  2024-03-23T00:00:00.000000000
# 24      1025         548   75      F  2024-02-14T00:00:00.000000000
# 25      1026         558   75      M  2024-01-30T00:00:00.000000000
# 32      1033         550   77      F  2024-02-16T00:00:00.000000000
# 40      1041         513   72      F  2024-01-29T00:00:00.000000000
# 48      1049         507   80      F  2024-03-27T00:00:00.000000000
# 49      1050         534   36      F  2024-02-24T00:00:00.000000000
# 56      1057         553   18      M  2024-03-07T00:00:00.000000000
# 105     1106         641   60      M  2024-02-07T00:00:00.000000000
# 109     1110         514   50      F  2024-03-26T00:00:00.000000000
# ...
